# %% [markdown]
# # ASSIGNMENT PRACTICE - SHOPPING LIST

# %%
"""
You have a shopping list with items and their prices:

shopping_list = [
    {"item": "Milk", "price": 50},
    {"item": "Bread", "price": 30},
    {"item": "Eggs", "price": 60},
    {"item": "Rice", "price": 120}
]
Complete the following tasks:

Task 1: Add and Remove Items (30 points)
Add a new item {"item": "Butter", "price": 80} to the shopping list
Remove the first item from the list using .pop(0)
Print how many items are in the list now

Task 2: Calculate Total Cost (35 points)
Calculate the total cost of all items in the shopping list
Find the most expensive item and print its name and price
Print the total cost

Task 3: Create Summary Dictionary (35 points)
Create a dictionary called summary with:
"total_items": Number of items in the list
"total_cost": Total price of all items
"average_price": Average price per item (round to 2 decimals)
Print the summary dictionary

"""

# %%
shopping_list = [
    {"item": "Milk", "price": 50},
    {"item": "Bread", "price": 30},
    {"item": "Eggs", "price": 60},
    {"item": "Rice", "price": 120}
]

shopping_list.append({"item": "Butter", "price": 80})
shopping_list.pop(0)
print(shopping_list)
# Out:
# [{'item': 'Bread', 'price': 30}, {'item': 'Eggs', 'price': 60}, {'item': 'Rice', 'price': 120}, {'item': 'Butter', 'price': 80}]

# %%
# Calculate the total cost of all items in the shopping list✔️

total = 0

for  price in shopping_list:
    # print(price["price"])
    total += price["price"]
print(f"The Total of all Items is - {total}")
# Out:
# The Total of all Items is - 290

# %%
# Find the most expensive item and print its name and price

max = 0
max_item =""


for price in shopping_list:

    Average = total / len(price["item"])

    if price["price"] > max:
        max = price["price"]
        max_item = price['item']
    
print(f"{max_item} - {max}")

print(f"{Average:.2f}")
# Out:
# Rice - 120
# 48.33

# %%
# Task 3: Create Summary Dictionary (35 points)
# Create a dictionary called summary with:
# "total_items": Number of items in the list
# "total_cost": Total price of all items
# "average_price": Average price per item (round to 2 decimals)
# Print the summary dictionary

average_price = round(Average , 2)

summary = {
    "total_items" : len(shopping_list),
    "total_cost"  : total,
    "Average_price" : average_price
}


print(summary)
# Out:
# {'total_items': 4, 'total_cost': 290, 'Average_price': 48.33}

# %%
shopping_list = [
    {"item": "Milk", "price": 50},
    {"item": "Bread", "price": 30},
    {"item": "Eggs", "price": 60},
    {"item": "Rice", "price": 120}
]

shopping_list.append({"item": "Butter", "price": 80})
shopping_list.pop(0)
print(shopping_list)

total = 0

for  price in shopping_list:
    # print(price["price"])
    total += price["price"]
print(f"The Total of all Items is - {total}")

max = 0
max_item =""

for price in shopping_list:
    if price["price"] > max:
        max = price["price"]
        max_item = price['item']
print(f"{max_item} - {max}")
average_price = round(Average , 2)


summary = {
    "total_items" : len(shopping_list),
    "total_cost"  : total,
    "Average_price" : average_price
}

print(summary)
# Out:
# [{'item': 'Bread', 'price': 30}, {'item': 'Eggs', 'price': 60}, {'item': 'Rice', 'price': 120}, {'item': 'Butter', 'price': 80}]
# The Total of all Items is - 290
# Rice - 120
# {'total_items': 4, 'total_cost': 290, 'Average_price': 48.33}
